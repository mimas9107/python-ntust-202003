# %%
import numpy as np
import requests
import matplotlib.pyplot as plt

# %%
# result = requests.get("https://tw.yahoo.com")

# %%
x = np.array(range(1,200))
y = 1/(1+x) * np.cos(x)*np.exp(-x/(2*np.pi))
font = {'family': 'SimSun',
        'color':  'black',
        'weight': 'normal',
        'size': 14,
        }

plt.plot(x,y)
plt.xlabel("x 軸", fontdict=font)
plt.ylabel("y 軸", fontdict=font)
# Out:
# Text(0, 0.5, 'y 軸')
